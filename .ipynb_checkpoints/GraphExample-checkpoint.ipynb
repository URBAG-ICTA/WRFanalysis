# %%
from src.URBAGgraphs import URBAGgraphs

# %%
# %matplotlib inline

# %%
ug = URBAGgraphs()

# %%
ug.load_file('./data/AirQualityData/example_01/polutantsSO2_2016-07.csv')

# %%
ug.df.head()
# Out:
#    Unnamed: 0  CODI EOI  CODI INE                    NOM ESTACIO AREA URBANA  \
# 0           0  43162005     43162  Vandellòs (Barranc del Terme)       rural
# 1           1  43162005     43162  Vandellòs (Barranc del Terme)       rural
# 2           2  43162005     43162  Vandellòs (Barranc del Terme)       rural
# 3           3  43162005     43162  Vandellòs (Barranc del Terme)       rural
# 4           4  43162005     43162  Vandellòs (Barranc del Terme)       rural
#
#                          MUNICIPI    LATITUD  LONGITUD  ALTITUD       DATA  \
# 0  Vandellòs i l'Hospitalet de l'  40.939439   0.83139       96 2016-07-15
# 1  Vandellòs i l'Hospitalet de l'  40.939439   0.83139       96 2016-07-15
# 2  Vandellòs i l'Hospitalet de l'  40.939439   0.83139       96 2016-07-15
# 3  Vandellòs i l'Hospitalet de l'  40.939439   0.83139       96 2016-07-15
# 4  Vandellòs i l'Hospitalet de l'  40.939439   0.83139       96 2016-07-15
#
#    YEAR  MONTH  DAY  HOUR  OBSERVATION  M_SO2_ppmv  M_T_celcius  \
# 0  2016      7   15     1          1.0    0.001995    17.369670
# 1  2016      7   15     2          1.0    0.002072    17.136534
# 2  2016      7   15     3          1.0    0.002138    16.919097
# 3  2016      7   15     4          1.0    0.002195    16.661719
# 4  2016      7   15     5          1.0    0.002181    16.448826
#
#              M_P  M_SO2_ug/m3
# 0  100696.671875     5.328512
# 1  100728.187500     5.540914
# 2  100751.375000     5.721897
# 3  100762.437500     5.879913
# 4  100772.085938     5.847936

# %%
estacions = ug.listEstacions()
estacions
# Out:
#                                                                                                                 CODI EOI
# NOM ESTACIO                              MUNICIPI                       LATITUD   LONGITUD ALTITUD AREA URBANA
# Alcover                                  Alcover                        41.278687 1.179898 238     rural             360
# Badalona                                 Badalona                       41.443985 2.237899 7       urban             360
# Barcelona (Eixample)                     Barcelona                      41.385315 2.153800 26      urban             360
# Barcelona (Gràcia - Sant Gervasi)        Barcelona                      41.398722 2.153399 57      urban             360
# Barcelona (Palau Reial)                  Barcelona                      41.387492 2.115200 81      urban             360
# Barcelona (Parc Vall Hebron)             Barcelona                      41.426109 2.148002 136     urban             360
# Berga                                    Berga                          42.097902 1.848201 661     peri-urban        360
# Castellet i la Gornal                    Castellet i la Gornal          41.244883 1.617700 213     rural             360
# Constantí                                Constantí                      41.154928 1.217701 56      peri-urban        360
# Cubelles (Poliesportiu)                  Cubelles                       41.202197 1.672200 5       peri-urban        360
# El Prat de Llobregat (Jardins de la Pau) Prat de Llobregat, el          41.321487 2.097702 5       peri-urban        360
# El Prat de Llobregat (Sagnier)           Prat de Llobregat, el          41.321773 2.082100 7       peri-urban        360
# Gavà                                     Gavà                           41.303095 1.991498 25      peri-urban        360
# Girona (Escola de Música)                Girona                         41.976378 2.816500 73      urban              72
# Igualada                                 Igualada                       41.578401 1.623006 311     peri-urban        360
# L'Ametlla de Mar                         Ametlla de Mar, l'             40.902483 0.809721 34      rural             360
# Lleida                                   Lleida                         41.615815 0.615700 220     urban             360
# Manlleu                                  Manlleu                        42.003307 2.287299 460     peri-urban        360
# Manresa                                  Manresa                        41.730292 1.825300 238     urban             360
# Mataró                                   Mataró                         41.547175 2.443298 40      urban             360
# Montcada i Reixac                        Montcada i Reixac              41.481972 2.188298 34      peri-urban        360
# Montsec                                  Sant Esteve de la Sarga        42.051321 0.729599 1570    rural             360
# Montseny (La Castanya)                   Montseny                       41.779280 2.358002 693     rural             360
# Pallejà (Roca de Vilana)                 Pallejà                        41.415280 1.990501 82      peri-urban        360
# Perafort (Puigdelfí)                     Perafort                       41.193603 1.236701 97      rural             360
# Rubí                                     Rubí                           41.492114 2.042497 171     peri-urban        336
# Sant Celoni                              Sant Celoni                    41.689097 2.495701 145     peri-urban        360
# Sant Feliu de Ll. (CEIP Marti i Pol)     Sant Feliu de Llobregat        41.386575 2.057400 81      peri-urban        360
# Sant Vicenç dels Horts                   Sant Vicenç dels Horts         41.400842 1.999720 65      peri-urban        336
# Sant Vicenç dels Horts (Ribot)           Sant Vicenç dels Horts         41.392190 2.009798 38      peri-urban        360
# Santa Perpètua de Mogoda                 Santa Perpètua de Mogoda       41.526720 2.183800 84      peri-urban        360
# Tarragona (Bonavista)                    Tarragona                      41.115910 1.191999 39      peri-urban        360
# Tarragona (Parc de la Ciutat)            Tarragona                      41.117399 1.241703 13      urban             360
# Tarragona (Sant Salvador)                Tarragona                      41.159512 1.239697 77      peri-urban        336
# Tarragona (Universitat Laboral)          Tarragona                      41.103706 1.200799 5       peri-urban        360
# Terrassa                                 Terrassa                       41.556113 2.007398 109     urban             360
# Vandellòs (Barranc del Terme)            Vandellòs i l'Hospitalet de l' 40.939439 0.831390 96      rural             360
# Vandellòs (Els Dedalts)                  Vandellòs i l'Hospitalet de l' 41.008079 0.831110 737     rural             360
# Vandellòs (Viver)                        Vandellòs i l'Hospitalet de l' 41.009454 0.912779 60      rural             360
# Vila-seca                                Vila-seca                      41.111956 1.151943 41      peri-urban        360
# Viladecans - Atrium                      Viladecans                     41.313351 2.013609 14      peri-urban        360
# Vilanova i la Geltrú                     Vilanova i la Geltrú           41.218985 1.721200 12      urban             360

# %% [markdown]
# <h3>Daily Profiles</h3>

# %%
#Error with bars and given by standard deviation
response = ug.plot_Daily_Profile_Error_Bars('SO2', ['Barcelona (Eixample)'], 'M', error = 'std', description=False)

# %%
#Error with bars and given by percentil 90
response = ug.plot_Daily_Profile_Error_Bars('SO2', ['Barcelona (Eixample)'], 'M', error = '90percentil', description=False)

# %%
#Error with area and given by percentil 90
response = ug.plot_Daily_Profile_Areas('SO2', ['Barcelona (Eixample)'], 'M', error = '90percentil', description=False)

# %%
#Plotting daily profile on all stations located in barcelona
response = ug.plot_Daily_Profile_Areas('SO2', ['Barcelona (Eixample)','Barcelona (Gràcia - Sant Gervasi)','Barcelona (Palau Reial)','Barcelona (Parc Vall Hebron)'], 'M', error = '90percentil', description=False)

# %% [markdown]
# <h3>Time Series</h3>

# %%
newdf = ug.plot_Time_Series_v1('SO2', 'Barcelona (Eixample)', 'M')

# %%
newdf = ug.plot_Time_Series_v1('SO2', 'Igualada', 'M')

# %%
newdf = ug.plot_Time_Series_v2('SO2', 'Barcelona (Eixample)', 'M')

# %% [markdown]
# <h3>Headmaps</h3>

# %%
## Stations versus days 
response = ug.plot_Matrix_Station_vs_Day('M', 'SO2')

# %%
response = ug.plot_Matrix_Station_vs_Hour('M', 'SO2')

# %%
response = ug.plot_Matrix_Day_vs_Hour('M', 'SO2')

# %% [markdown]
# <h3>Correlation Observation vs predicted by Station</h3>

# %%
ug.plot_Station_Correlation('M', 'SO2')
